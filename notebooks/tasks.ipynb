# %%
# %load_ext autoreload
# %autoreload 2

import np_datajoint
from np_datajoint.classes import *
from np_datajoint.comparisons import *
from np_datajoint.config import *
from np_datajoint.utils import *
import notebook_setup

DEBUG = False
# Out:
# [2022-12-16 15:54:28,981][INFO]: Connecting bjhardcastle@rds.datajoint.io:3306
# [2022-12-16 15:54:29,526][INFO]: Connected bjhardcastle@rds.datajoint.io:3306

# %% [markdown]
# # Upload raw data from A:/B:
# - select session to upload
# - **de-select probes that weren't inserted**
# - hit `Upload` and leave this page open: upload will take at approx. 3 hours

# %%
session_upload_from_acq_widget()
# Out:
# TwoByTwoLayout(children=(Dropdown(description='session', layout=Layout(grid_area='top-left'), options=('000000…
# 00:46 | Connecting to HPC via SSH, logs will continue in /allen/ai/homedirs/svc_neuropix
# 00:46 | Connected (version 2.0, client OpenSSH_7.4)
# 00:46 | Authentication (publickey) successful!
# 00:47 | [chan 0] Opened sftp connection (server version 3)
# Submitted batch job 7296847
#
# 00:47 | submitted: slurm.sbatch python upload_session.py --session 1234028213_640887_20221219 --paths //allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1200280254/ecephys_session_1234028213/1234028213_640887_20221219_probeABC //allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1200280254/ecephys_session_1234028213/1234028213_640887_20221219_probeDEF --probes ABCDEF
# python upload_session.py --session 1234028213_640887_20221219 --paths //allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1200280254/ecephys_session_1234028213/1234028213_640887_20221219_probeABC //allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1200280254/ecephys_session_1234028213/1234028213_640887_20221219_probeDEF --probes ABCDEF
# 00:47 | Exited normally after 0:00:00.594735 [h:m:s.Î¼s]
# 00:47 | Connecting to HPC via SSH, logs will continue in /allen/ai/homedirs/svc_neuropix
# 00:47 | Connected (version 2.0, client OpenSSH_7.4)
# 00:47 | Authentication (publickey) successful!
# 00:47 | [chan 0] Opened sftp connection (server version 3)
# Submitted batch job 7296848
#
# 00:47 | submitted: slurm.sbatch python upload_session.py --session 1234203203_640887_20221220 --paths //allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1200280254/ecephys_session_1234203203/1234203203_640887_20221220_probeABC //allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1200280254/ecephys_session_1234203203/1234203203_640887_20221220_probeDEF --probes ABCDEF
# python upload_session.py --session 1234203203_640887_20221220 --paths //allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1200280254/ecephys_session_1234203203/1234203203_640887_20221220_probeABC //allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1200280254/ecephys_session_1234203203/1234203203_640887_20221220_probeDEF --probes ABCDEF
# 00:47 | Exited normally after 0:00:00.499805 [h:m:s.Î¼s]
# raw data folders are not within 2 GB of each other
# 00:49 | Connecting to HPC via SSH, logs will continue in /allen/ai/homedirs/svc_neuropix
# 00:49 | Connected (version 2.0, client OpenSSH_7.4)
# 00:49 | Authentication (publickey) successful!
# 00:49 | [chan 0] Opened sftp connection (server version 3)
# Submitted batch job 7296849
#
# 00:49 | submitted: slurm.sbatch python upload_session.py --session 1234410451_640887_20221221 --paths //allen/programs/mindscope/workgroups/np-exp/1234410451_640887_20221221/1234410451_640887_20221221_probeABC //allen/programs/mindscope/workgroups/np-exp/1234410451_640887_20221221/1234410451_640887_20221221_probeDEF --probes ABCEF
# python upload_session.py --session 1234410451_640887_20221221 --paths //allen/programs/mindscope/workgroups/np-exp/1234410451_640887_20221221/1234410451_640887_20221221_probeABC //allen/programs/mindscope/workgroups/np-exp/1234410451_640887_20221221/1234410451_640887_20221221_probeDEF --probes ABCEF
# 00:49 | Exited normally after 0:00:00.489787 [h:m:s.Î¼s]

# %% [markdown]
# - `paramset_idx=1`      : probes with clustering tasks using this paramset_idx
# - `paramset_idx=-1`     : probes with no paramset_idx (haven't started processing)
# - `paramset_idx=None`   : all probes, with or without clustering tasks

# %%
sorting_summary(paramset_idx=0)
# Out:
#                             probes  ephys  task  clustering  metrics  \
# session
# 1191631184_615047_20220714       6      6     6           6        6
# 1191131853_615047_20220712       6      6     6           6        6
# 1190892228_615047_20220711       6      6     6           6        6
# 1187940755_614608_20220629       3      3     3           3        3
#
#                             waveform  curated         pidx_done  all_done
# session
# 1191631184_615047_20220714         6        6  0, 1, 2, 3, 4, 5         1
# 1191131853_615047_20220712         6        6  0, 1, 2, 3, 4, 5         1
# 1190892228_615047_20220711         6        6  0, 5, 4, 3, 2, 1         1
# 1187940755_614608_20220629         3        3           3, 4, 5         1

# %%
for paramset_idx in (-1, 1):
    print(f'{paramset_idx=}')
    display(sorting_summary(paramset_idx))
# Out:
# paramset_idx=-1
#                             probes  ephys  task  clustering  metrics  \
# session
# 1233182785_640890_20221215       0      0     0           0        0
# 1232430325_640890_20221212       0      0     0           0        0
# 1231476077_637488_20221208       0      0     0           0        0
# 1208053773_623319_20220907       0      0     0           0        0
# 1198796984_615564_20220815       0      0     0           0        0
#
#                             waveform  curated pidx_done  all_done
# session
# 1233182785_640890_20221215         0        0      None         0
# 1232430325_640890_20221212         0        0      None         0
# 1231476077_637488_20221208         0        0      None         0
# 1208053773_623319_20220907         0        0      None         0
# 1198796984_615564_20220815         0        0      None         0
# paramset_idx=1
#                             probes  ephys  task  clustering  metrics  \
# session
# 1232954220_640890_20221214       6      6     6           6        6
# 1232725697_640890_20221213       6      5     5           5        5
# 1231219674_637488_20221207       6      6     6           6        6
# 1230962048_637488_20221206       6      6     6           6        6
# 1230732154_637488_20221205       6      6     6           4        4
# ...                            ...    ...   ...         ...      ...
# 1189336645_611166_20220705       6      6     6           6        6
# 1188138256_614608_20220630       6      6     6           6        6
# 1187668018_614608_20220628       6      5     5           5        5
# 1187475832_614608_20220627       6      5     5           5        5
# 1185043018_608980_20220616       6      6     6           6        6
#
#                             waveform  curated         pidx_done  all_done
# session
# 1232954220_640890_20221214         6        6  0, 1, 2, 3, 4, 5         1
# 1232725697_640890_20221213         5        5     0, 1, 2, 3, 5         1
# 1231219674_637488_20221207         6        6  0, 1, 2, 3, 4, 5         1
# 1230962048_637488_20221206         6        6  0, 1, 2, 3, 4, 5         1
# 1230732154_637488_20221205         4        4        1, 3, 4, 5         0
# ...                              ...      ...               ...       ...
# 1189336645_611166_20220705         6        6  0, 1, 2, 3, 4, 5         1
# 1188138256_614608_20220630         6        6  0, 1, 2, 3, 4, 5         1
# 1187668018_614608_20220628         5        5     0, 1, 2, 3, 4         1
# 1187475832_614608_20220627         5        5     0, 1, 2, 3, 4         1
# 1185043018_608980_20220616         6        6  0, 1, 2, 3, 4, 5         1
#
# [61 rows x 9 columns]

# %%
DataJointSession('1232430325_640890_20221212').upload(probes='ABCDEF')
# Out:
# 17:14 | Connecting to HPC via SSH, logs will continue in /allen/ai/homedirs/svc_neuropix
# 17:14 | Connected (version 2.0, client OpenSSH_7.4)
# 17:14 | Authentication (publickey) successful!
# 17:14 | [chan 0] Opened sftp connection (server version 3)
# Submitted batch job 7253585
#
# 17:14 | Exited normally after 0:00:00.441803 [h:m:s.Î¼s]

# %%
DataJointSession('1200878248_623322_20220825').lims_path
# Out:
# {'id': 1200878248,
#  'name': '20220825123122_1125678056',
#  'stimulus_name': None,
#  'storage_directory': None,
#  'workflow_state': 'created',
#  'date_of_acquisition': None,
#  'operator': {'id': 1125678056,
#   'login': 'henry.loeffler',
#   'created_at': '2021-09-01T09:18:03.048-07:00',
#   'updated_at': '2021-09-01T09:18:03.159-07:00',
#   'group_override': None,
#   'use_custom_header': False,
#   'siv_default_ontology_id': None,
#   'siv_default_graph_id': None,
#   'siv_default_cortex_layer_ontology_id': None,
#   'siv_default_cortex_layer_graph_id': None,
#   'jobs_update': False},
#  'specimen': {'id': 1170989461,
#   'name': 'C57BL6J-623322',
#   'plane_of_section_id': 1,
#   'frozen_at': '2022-08-26T12:00:00.000-07:00',
#   'rna_integrity_number': None,
#   'tissue_ph': None,
#   'hemisphere_id': None,
#   'created_by': None,
#   'created_at': '2022-04-15T15:06:43.232-07:00',
#   'updated_by': None,
#   'updated_at': '2022-09-21T10:51:41.964-07:00',
#   'parent_id': None,
#   'structure_id': None,
#   'postmortem_interval_id': None,
#   'preparation_method_id': None,
#   'parent_x_coord': None,
#   'parent_y_coord': None,
#   'parent_z_coord': None,
#   'barcode': '1170989461',
#   'location_id': None,
#   'storage_directory': '/allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1170989461/',
#   'project_id': 1161712663,
#   'specimen_preparation_method_id': 283,
#   'alignment3d_id': None,
#   'reference_space_id': 9,
#   'external_specimen_name': '623322',
#   'normalization_group_id': None,
#   'carousel_well_name': None,
#   'donor_id': 1170989456,
#   'ephys_cell_plan_id': None,
#   'ephys_roi_result_id': None,
#   'histology_well_name': None,
#   'priority': None,
#   'ephys_neural_tissue_plan_id': None,
#   'tissue_processing_id': None,
#   'task_flow_id': None,
#   'specimen_set_id': None,
#   'biophysical_model_state': 'review_required',
#   'cell_prep_id': None,
#   'data': None,
#   'cell_depth': None,
#   'cell_reporter_id': None,
#   'facs_well_id': None,
#   'patched_cell_container': None,
#   'cortex_layer_id': None,
#   'cell_label': None,
#   'flipped_specimen_id': 561557765,
#   'operation_id': None,
#   'pinned_radius': None,
#   'x_coord': None,
#   'y_coord': None,
#   'ephys_qc_result': None,
#   'ephys_start_time_sec': None,
#   'starter_cell_count': None,
#   'task_id': None,
#   'workflow_state': 'pending',
#   'mfish_experiment_id': None,
#   'sectioning_task_id': None,
#   'merscope_experiment_id': None},
#  'ecephys_probes': [],
#  'project': {'id': 1126885041,
#   'name': 'Developing a new surgery that will give us recording access to the entire left hemisphere and enable us to follow brain activity from sensory input to motor output during visual behavior',
#   'code': 'DynamicRoutingSurgicalDevelopment',
#   'created_at': '2021-09-07T12:17:08.907-07:00',
#   'updated_at': '2022-09-17T01:06:07.572-07:00',
#   'file_storage': '/allen/programs/mindscope/production/dynamicrouting/',
#   'subdirectory_count': 226,
#   'current_directory': 4,
#   'trigger_dir': '/allen/programs/mindscope/production/incoming/trigger/',
#   'failed_trigger_dir': '/allen/programs/mindscope/production/incoming/failed_trigger/',
#   'process_triggers': True,
#   'incoming_directory': None,
#   'non_cached_schema_name': None},
#  'isi_experiment': {'id': 1174501765,
#   'name': '20220502_623322',
#   'storage_directory': '/allen/programs/mindscope/production/dynamicrouting/prod0/specimen_1170989461/isi_experiment_1174501765/',
#   'workflow_state': 'passed',
#   'specimen_id': 1170989461,
#   'temp_upload_directory': '/allen/programs/mindscope/production/incoming/',
#   'date_of_acquisition': '2022-05-02T00:00:00.000-07:00',
#   'equipment_id': 481006105,
#   'operator_id': 1113743755,
#   'qc_operator_id': None,
#   'project_id': 1126885041,
#   'manual_correction_only': True,
#   'vasculature_image_id': 1174555140,
#   'retinotopy_vertical_image_id': 1174555128,
#   'retinotopy_horizontal_image_id': 1174555131,
#   'sign_map_image_id': 1174555137,
#   'isi_imaging_plane_image_id': 1174555143,
#   'isi_overlay_image_id': 1174555149,
#   'eccentricity_retinotopic_zero_image_id': 1174555152,
#   'eccentricity_v_one_centroid_image_id': 1174555155,
#   'target_map_image_id': 1174555161}}

# %%
s = dj.Schema('mindscope_dynamic-routing_ephys')
s.log
# Out:
# *id    timestamp      version      user           host           event
# +----+ +------------+ +----------+ +------------+ +------------+ +------------+
# 1      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   created
# 2      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 3      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 4      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 5      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 6      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 7      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 8      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 9      2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 10     2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 11     2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
# 12     2022-04-22 23: 0.13.4py     mindscope-work 79026b62f8fb   Declared `mind
#    ...
#  (Total: 51)

# %% [markdown]
# # Problem with this probe's cluster metrics table (empty)

# %%
self = comparisons.ProbeDataJoint('1190094328_611166_20220707', 'C')
query = {
    'insertion_number': self.probe_idx,
    'paramset_idx': self.paramset_idx,
}
query = query | self.session.session_key
metrics = dj_ephys.QualityMetrics.Cluster & query
metrics
# Out:
# *subject    *session_id    *insertion_num *paramset_idx  *unit    firing_rate    snr     presence_ratio isi_violation  number_violati amplitude_cuto isolation_dist l_ratio     d_prime     nn_hit_rate    nn_miss_rate   silhouette_sco max_drift     cumulative_dri contamination_
# +---------+ +------------+ +------------+ +------------+ +------+ +------------+ +-----+ +------------+ +------------+ +------------+ +------------+ +------------+ +---------+ +---------+ +------------+ +------------+ +------------+ +-----------+ +------------+ +------------+
#
#  (Total: 0)

# %%
# for session in sorted_sessions():
sessions = (
    DataJointSession(s) for s in (
    '1200878248_623322_20220825',
    )
)
for session in sessions:
    try:
        session.download(paramset_idx=1)
        session.download(paramset_idx=2)
    except:
        logging.exception(f'Download failed {session.session_folder}')
# Out:
# 12:33 | Finished downloading sorted data for 1200878248_623322_20220825
# 12:39 | Finished downloading sorted data for 1200878248_623322_20220825
# 12:43 | Finished downloading sorted data for 1225178442_633232_20221110
# 12:43 | Finished downloading sorted data for 1225178442_633232_20221110
# 12:48 | Finished downloading sorted data for 1224928532_633232_20221109
# 12:48 | Finished downloading sorted data for 1224928532_633232_20221109
# 12:51 | Finished downloading sorted data for 1224385827_633232_20221107
# 12:51 | Finished downloading sorted data for 1224385827_633232_20221107

# %%
DataJointSession('1230732154_637488_20221205').download()
# Out:
# 19:36 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:36 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:36 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:36 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:36 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:37 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:37 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:37 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:38 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:39 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:39 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:39 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:39 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:40 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:41 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:42 | Connection pool is full, discarding connection: dj-sciops.s3-accelerate.amazonaws.com. Connection pool size: 10
# 19:43 | Finished downloading sorted data for 1230732154_637488_20221205

# %%
for session in sorted_sessions():
    session.download(paramset_idx=2)
# Out:
# 09:18 | Finished downloading sorted data for 1230962048_637488_20221206
# 09:18 | Finished downloading sorted data for 1230064747_638387_20221202
# 09:18 | Finished downloading sorted data for 1229887685_638387_20221201
# 09:18 | Finished downloading sorted data for 1229654875_638387_20221130
# 09:18 | Finished downloading sorted data for 1227855488_637483_20221122
# 09:18 | Finished downloading sorted data for 1227622013_637483_20221121
# 09:18 | Finished downloading sorted data for 1226780656_636740_20221117
# 09:18 | Finished downloading sorted data for 1226528572_636740_20221116
# 09:18 | Finished downloading sorted data for 1226251663_636740_20221115
# 09:18 | Finished downloading sorted data for 1226010097_636740_20221114
# 09:18 | Finished downloading sorted data for 1225178442_633232_20221110
# 09:18 | Finished downloading sorted data for 1224928532_633232_20221109
# 09:18 | Finished downloading sorted data for 1224385827_633232_20221107
# 09:18 | Finished downloading sorted data for 1216100684_632296_20221006
# 09:18 | Finished downloading sorted data for 1215593634_632296_20221004
# 09:18 | Finished downloading sorted data for 1215407402_632296_20221003
# 09:18 | Finished downloading sorted data for 1214740195_626279_20220929
# 09:18 | Finished downloading sorted data for 1214566710_626279_20220928
# 09:18 | Finished downloading sorted data for 1214217748_626279_20220926
# 09:18 | Finished downloading sorted data for 1211232400_623786_20220915
# 09:18 | Finished downloading sorted data for 1210863396_623786_20220914
# 09:18 | Finished downloading sorted data for 1210608527_623786_20220913
# 09:18 | Finished downloading sorted data for 1210343162_623786_20220912
# 09:18 | Finished downloading sorted data for 1208664393_623319_20220908
# 09:18 | Finished downloading sorted data for 1204636084_623784_20220901
# 09:18 | Finished downloading sorted data for 1203574877_623784_20220831
# 09:18 | Finished downloading sorted data for 1202644967_623784_20220830
# 09:18 | Finished downloading sorted data for 1202438738_623784_20220829
# 09:23 | Finished downloading sorted data for 1200878248_623322_20220825
# 09:23 | Finished downloading sorted data for 1200260055_623322_20220822
# 09:23 | Finished downloading sorted data for 1199448636_615564_20220818
# 09:23 | Finished downloading sorted data for 1199249150_615564_20220817
# 09:23 | Finished downloading sorted data for 1198995158_615564_20220816
# 09:23 | Finished downloading sorted data for 1198130743_615048_20220812
# 09:23 | Finished downloading sorted data for 1197967151_615048_20220811
# 09:23 | Finished downloading sorted data for 1197514969_615048_20220809
# ---------------------------------------------------------------------------
# InvalidObjectState                        Traceback (most recent call last)
# Cell In[30], line 2
#       1 for session in sorted_sessions():
# ----> 2     session.download(paramset_idx=2)
#
# File c:\Users\ben.hardcastle\github\np_datajoint\utils.py:523, in DataJointSession.download(self, paramset_idx)
#     521         trailing_slash = '/' if 'win' not in sys.platform else '\\'
#     522         for src, dest in zip(src_list, dest_list):
# --> 523             S3_SESSION.s3.Bucket(S3_BUCKET).download_file(
#     524                 Key=src,
#     525                 Filename=dest,
#     526                 Config=dj_axon.boto3.s3.transfer.TransferConfig(**BOTO3_CONFIG),
#     527             )
#     528         self.update_metrics_csv_with_missing_columns(probe_idx, sorted_paramset_idx)
#     529 logging.info(
#     530     f"Finished downloading sorted data for {self.session_folder}"
#     531 )
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\boto3\s3\inject.py:277, in bucket_download_file(self, Key, Filename, ExtraArgs, Callback, Config)
#     243 def bucket_download_file(
#     244     self, Key, Filename, ExtraArgs=None, Callback=None, Config=None
#     245 ):
#     246     """Download an S3 object to a file.
#     247
#     248     Usage::
#    (...)
#     275         transfer.
#     276     """
# --> 277     return self.meta.client.download_file(
#     278         Bucket=self.name,
#     279         Key=Key,
#     280         Filename=Filename,
#     281         ExtraArgs=ExtraArgs,
#     282         Callback=Callback,
#     283         Config=Config,
#     284     )
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\boto3\s3\inject.py:190, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     155 """Download an S3 object to a file.
#     156
#     157 Usage::
#    (...)
#     187     transfer.
#     188 """
#     189 with S3Transfer(self, Config) as transfer:
# --> 190     return transfer.download_file(
#     191         bucket=Bucket,
#     192         key=Key,
#     193         filename=Filename,
#     194         extra_args=ExtraArgs,
#     195         callback=Callback,
#     196     )
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\boto3\s3\transfer.py:320, in S3Transfer.download_file(self, bucket, key, filename, extra_args, callback)
#     316 future = self._manager.download(
#     317     bucket, key, filename, extra_args, subscribers
#     318 )
#     319 try:
# --> 320     future.result()
#     321 # This is for backwards compatibility where when retries are
#     322 # exceeded we need to throw the same error from boto3 instead of
#     323 # s3transfer's built in RetriesExceededError as current users are
#     324 # catching the boto3 one instead of the s3transfer exception to do
#     325 # their own retries.
#     326 except S3TransferRetriesExceededError as e:
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\s3transfer\futures.py:103, in TransferFuture.result(self)
#      98 def result(self):
#      99     try:
#     100         # Usually the result() method blocks until the transfer is done,
#     101         # however if a KeyboardInterrupt is raised we want want to exit
#     102         # out of this and propagate the exception.
# --> 103         return self._coordinator.result()
#     104     except KeyboardInterrupt as e:
#     105         self.cancel()
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\s3transfer\futures.py:266, in TransferCoordinator.result(self)
#     263 # Once done waiting, raise an exception if present or return the
#     264 # final result.
#     265 if self._exception:
# --> 266     raise self._exception
#     267 return self._result
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\s3transfer\tasks.py:139, in Task.__call__(self)
#     135     # If the task is not done (really only if some other related
#     136     # task to the TransferFuture had failed) then execute the task's
#     137     # main() method.
#     138     if not self._transfer_coordinator.done():
# --> 139         return self._execute_main(kwargs)
#     140 except Exception as e:
#     141     self._log_and_set_exception(e)
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\s3transfer\tasks.py:162, in Task._execute_main(self, kwargs)
#     159 # Log what is about to be executed.
#     160 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 162 return_value = self._main(**kwargs)
#     163 # If the task is the final task, then set the TransferFuture's
#     164 # value to the return value from main().
#     165 if self._is_final:
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\s3transfer\download.py:569, in GetObjectTask._main(self, client, bucket, key, fileobj, extra_args, callbacks, max_attempts, download_output_manager, io_chunksize, start_index, bandwidth_limiter)
#     567 try:
#     568     current_index = start_index
# --> 569     response = client.get_object(
#     570         Bucket=bucket, Key=key, **extra_args
#     571     )
#     572     streaming_body = StreamReaderProgress(
#     573         response['Body'], callbacks
#     574     )
#     575     if bandwidth_limiter:
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\botocore\client.py:530, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     526     raise TypeError(
#     527         f"{py_operation_name}() only accepts keyword arguments."
#     528     )
#     529 # The "self" in this scope is referring to the BaseClient.
# --> 530 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\ben.hardcastle\Anaconda3\envs\dj1\lib\site-packages\botocore\client.py:960, in BaseClient._make_api_call(self, operation_name, api_params)
#     958     error_code = parsed_response.get("Error", {}).get("Code")
#     959     error_class = self.exceptions.from_code(error_code)
# --> 960     raise error_class(parsed_response, operation_name)
#     961 else:
#     962     return parsed_response
#
# InvalidObjectState: An error occurred (InvalidObjectState) when calling the GetObject operation: The operation is not valid for the object's access tier
