# %%
# %load_ext autoreload
# %autoreload 2

from utils import *
df = sorting_summary()
# Out:
# c:\Users\ben.hardcastle\Anaconda3\envs\datajoint\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# [2022-10-30 09:21:46,781][get_config][INFO]: Existing configuration detected. Loading from C:\Users\ben.hardcastle\AppData\Local\datajoint\djsciops\config.yaml...
# [2022-10-30 09:21:48,105][INFO]: Connecting bjhardcastle@rds.datajoint.io:3306
# [2022-10-30 09:21:48,647][INFO]: Connected bjhardcastle@rds.datajoint.io:3306
# [2022-10-30 09:21:55,691][get_config][INFO]: Existing configuration detected. Loading from C:\Users\ben.hardcastle\AppData\Local\datajoint\djsciops\config.yaml...
# ...
# [2022-10-30 09:21:57,297][flush][INFO]: 0%|          | 0.00/6.27k [00:00<?, ?B/s]
# ...

# %%
sorting_summary()
# Out:
#                             insertion  ephys_recording  lfp  clustering_task  \
# session
# 1216100684_632296_20221006          0                0    0                0
# 1215593634_632296_20221004          0                0    0                0
# 1215407402_632296_20221003          0                0    0                0
# 1214740195_626279_20220929          0                0    0                0
# 1214566710_626279_20220928          0                0    0                0
# 1214217748_626279_20220926          0                0    0                0
# 1211232400_623786_20220915          0                0    0                0
# 1210863396_623786_20220914          0                0    0                0
# 1210608527_623786_20220913          0                0    0                0
# 1210343162_623786_20220912          0                0    0                0
# 1208664393_623319_20220908          6                6    6                6
# ...

# %%
database_diagram()
# Out:
# c:\Users\ben.hardcastle\Anaconda3\envs\datajoint\lib\inspect.py:469: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   value = getattr(object, key)
# c:\Users\ben.hardcastle\Anaconda3\envs\datajoint\lib\inspect.py:469: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   value = getattr(object, key)
# c:\Users\ben.hardcastle\Anaconda3\envs\datajoint\lib\inspect.py:469: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   value = getattr(object, key)

# %%
session = DataJointSession('1188138256_614608_20220630')
# (session.metrics & {'insertion_number': 0}).fetch1('metrics')
(session.curated_clustering.Unit &
                f'insertion_number={0}' & 
                f'paramset_idx={1}' &
                'cluster_quality_label = "good"')
# Out:
# *subject    *session_id    *insertion_num *paramset_idx  *unit    electrode_conf probe_type     electrode     cluster_qualit spike_count    spike_time spike_site spike_dept
# +---------+ +------------+ +------------+ +------------+ +------+ +------------+ +------------+ +-----------+ +------------+ +------------+ +--------+ +--------+ +--------+
# 608671      2              0              1              4        6f6d8149-1603- neuropixels 1. 19            good           58             =BLOB=     =BLOB=     =BLOB=
# 608671      2              0              1              19       6f6d8149-1603- neuropixels 1. 107           good           99             =BLOB=     =BLOB=     =BLOB=
# 608671      2              0              1              27       6f6d8149-1603- neuropixels 1. 225           good           17152          =BLOB=     =BLOB=     =BLOB=
# ...

# %%
for session_str in df.index:
    session = DataJointSession(session_str)
    session.download()
